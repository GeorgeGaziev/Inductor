# %% [markdown]
# # Parser

# %%
import urllib
from bs4 import BeautifulSoup
import pickle
from collections import Counter
from collections import namedtuple
import re
import xlwings as xw
import pandas as pd
import numpy as np

# %%
url_male="https://ru.wikipedia.org/wiki/Категория:Мужские_имена"
url_male="https://ru.wikipedia.org/wiki/Категория:Женские_имена"

# %%
#Перревожу в формат понятный bs4
url_male_q=urllib.request.quote(url_male,"/:")
url_female_q=urllib.request.quote(url_male,"/:")

# %%
# Получаю код страницы
male_bs=BeautifulSoup(urllib.request.urlopen(url_male_q),"lxml")
female_bs=BeautifulSoup(urllib.request.urlopen(url_female_q),"lxml")

# %%
#На одной странице получаю все имена и сслки на них
male_list=[]
for letter in male_bs.find_all("div",{"id":"mw-pages"})[0].find_all("div",class_="mw-category-group"):
    for j in letter.find_all("a",href=True):
        male_list.append([j.contents[0].split(" ")[0],"https://ru.wikipedia.org"+j["href"]])

# %%
male_list
# Out:
# [['Августа',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D0%B3%D1%83%D1%81%D1%82%D0%B0'],
#  ['Автоноя',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%82%D0%BE%D0%BD%D0%BE%D1%8F'],
#  ['Агата', 'https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%B0%D1%82%D0%B0'],
#  ['Агафья',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%B0%D1%84%D1%8C%D1%8F'],
#  ['Аглая', 'https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%BB%D0%B0%D1%8F'],
#  ['Агнес', 'https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%BD%D0%B5%D1%81'],
#  ['Агнета',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%BD%D0%B5%D1%82%D0%B0'],
#  ['Аделаида',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B4%D0%B5%D0%BB%D0%B0%D0%B8%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Аделина',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B4%D0%B5%D0%BB%D0%B8%D0%BD%D0%B0'],
#  ['Адриана',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B4%D1%80%D0%B8%D0%B0%D0%BD%D0%B0'],
#  ['Адриенна',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B4%D1%80%D0%B8%D0%B5%D0%BD%D0%BD%D0%B0'],
#  ['Азиза',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B7%D0%B8%D0%B7%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Аида',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B8%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Айганым',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B9%D0%B3%D0%B0%D0%BD%D1%8B%D0%BC'],
#  ['Айгерим',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%B9%D0%B3%D0%B5%D1%80%D0%B8%D0%BC'],
#  ['Алдона',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B4%D0%BE%D0%BD%D0%B0'],
#  ['Алевтина',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B5%D0%B2%D1%82%D0%B8%D0%BD%D0%B0'],
#  ['Александра',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B5%D0%BA%D1%81%D0%B0%D0%BD%D0%B4%D1%80%D0%B0'],
#  ['Алима',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B8%D0%BC%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Алина', 'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B8%D0%BD%D0%B0'],
#  ['Алиса',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B8%D1%81%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Алия',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Алла', 'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D0%BB%D0%B0'],
#  ['Алтжин',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D1%82%D0%B6%D0%B8%D0%BD'],
#  ['Альбина',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BB%D1%8C%D0%B1%D0%B8%D0%BD%D0%B0'],
#  ['Амалия',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BC%D0%B0%D0%BB%D0%B8%D1%8F'],
#  ['Аманда',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BC%D0%B0%D0%BD%D0%B4%D0%B0'],
#  ['Амина', 'https://ru.wikipedia.org/wiki/%D0%90%D0%BC%D0%B8%D0%BD%D0%B0'],
#  ['Амира', 'https://ru.wikipedia.org/wiki/%D0%90%D0%BC%D0%B8%D1%80%D0%B0'],
#  ['Анаис', 'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B0%D0%B8%D1%81'],
#  ['Анастасия',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B0%D1%81%D1%82%D0%B0%D1%81%D0%B8%D1%8F'],
#  ['Ангелина',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B3%D0%B5%D0%BB%D0%B8%D0%BD%D0%B0'],
#  ['Анжела',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B6%D0%B5%D0%BB%D0%B0'],
#  ['Анжелика',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B6%D0%B5%D0%BB%D0%B8%D0%BA%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Анисия',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%B8%D1%81%D0%B8%D1%8F'],
#  ['Анна',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Антонина',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BD%D1%82%D0%BE%D0%BD%D0%B8%D0%BD%D0%B0'],
#  ['Аполлинария',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BF%D0%BE%D0%BB%D0%BB%D0%B8%D0%BD%D0%B0%D1%80%D0%B8%D1%8F'],
#  ['Аполлония',
#   'https://ru.wikipedia.org/wiki/%D0%90%D0%BF%D0%BE%D0%BB%D0%BB%D0%BE%D0%BD%D0%B8%D1%8F'],
#  ['Ассоль',
#   'https://ru.wikipedia.org/wiki/%D0%90%D1%81%D1%81%D0%BE%D0%BB%D1%8C_(%D0%B8%D0%BC%D1%8F)'],
#  ['Бажена',
#   'https://ru.wikipedia.org/wiki/%D0%91%D0%B0%D0%B6%D0%B5%D0%BD%D0%B0'],
#  ['Беата', 'https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B0%D1%82%D0%B0'],
#  ['Беатриса',
#   'https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B0%D1%82%D1%80%D0%B8%D1%81%D0%B0'],
#  ['Белла',
#   'https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%BB%D0%BB%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Божена',
#   'https://ru.wikipedia.org/wiki/%D0%91%D0%BE%D0%B6%D0%B5%D0%BD%D0%B0'],
#  ['Валентина',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D0%BB%D0%B5%D0%BD%D1%82%D0%B8%D0%BD%D0%B0'],
#  ['Валерия',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F'],
#  ['Ванда',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D0%BD%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Варвара',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D1%80%D0%B2%D0%B0%D1%80%D0%B0'],
#  ['Василиса',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D1%81%D0%B8%D0%BB%D0%B8%D1%81%D0%B0'],
#  ['Васса', 'https://ru.wikipedia.org/wiki/%D0%92%D0%B0%D1%81%D1%81%D0%B0'],
#  ['Венди', 'https://ru.wikipedia.org/wiki/%D0%92%D0%B5%D0%BD%D0%B4%D0%B8'],
#  ['Вера',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B5%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Вероника',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B5%D1%80%D0%BE%D0%BD%D0%B8%D0%BA%D0%B0'],
#  ['Виктория',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D1%82%D0%BE%D1%80%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Виолетта',
#   'https://ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BE%D0%BB%D0%B5%D1%82%D1%82%D0%B0'],
#  ['Габриеле',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%B0%D0%B1%D1%80%D0%B8%D0%B5%D0%BB%D0%B5'],
#  ['Галина',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%B0%D0%BB%D0%B8%D0%BD%D0%B0'],
#  ['Гликерия',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%BB%D0%B8%D0%BA%D0%B5%D1%80%D0%B8%D1%8F'],
#  ['Гоар',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D0%B0%D1%80_(%D0%B6%D0%B5%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%B8%D0%BC%D1%8F)'],
#  ['Говхар',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D0%B2%D1%85%D0%B0%D1%80_(%D0%B6%D0%B5%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%B8%D0%BC%D1%8F)'],
#  ['Горица',
#   'https://ru.wikipedia.org/wiki/%D0%93%D0%BE%D1%80%D0%B8%D1%86%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Грета',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%80%D0%B5%D1%82%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Гульмира',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%83%D0%BB%D1%8C%D0%BC%D0%B8%D1%80%D0%B0'],
#  ['Гульназ',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%83%D0%BB%D1%8C%D0%BD%D0%B0%D0%B7'],
#  ['Гульнара',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%83%D0%BB%D1%8C%D0%BD%D0%B0%D1%80%D0%B0'],
#  ['Гуннхильда',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%83%D0%BD%D0%BD%D1%85%D0%B8%D0%BB%D1%8C%D0%B4%D0%B0'],
#  ['Гюльджан',
#   'https://ru.wikipedia.org/wiki/%D0%93%D1%8E%D0%BB%D1%8C%D0%B4%D0%B6%D0%B0%D0%BD'],
#  ['Дана',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D0%BD%D0%B0_(%D0%B6%D0%B5%D0%BD%D1%81%D0%BA%D0%BE%D0%B5_%D0%B8%D0%BC%D1%8F)'],
#  ['Дарерка',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D1%80%D0%B5%D1%80%D0%BA%D0%B0'],
#  ['Дарья', 'https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D1%80%D1%8C%D1%8F'],
#  ['Дебора',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B5%D0%B1%D0%BE%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Джанет',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D0%B0%D0%BD%D0%B5%D1%82'],
#  ['Дженифер',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D0%B5%D0%BD%D0%B8%D1%84%D0%B5%D1%80'],
#  ['Дженна',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D0%B5%D0%BD%D0%BD%D0%B0'],
#  ['Джоан', 'https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D0%BE%D0%B0%D0%BD'],
#  ['Джулия',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B6%D1%83%D0%BB%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Диана',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%B0%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Диля',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BB%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Дина',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Динора',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%BE%D1%80%D0%B0'],
#  ['Дита', 'https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D1%82%D0%B0'],
#  ['Домна',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BC%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Дора',
#   'https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Ева',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Евгения',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D0%B3%D0%B5%D0%BD%D0%B8%D1%8F'],
#  ['Евдокия',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D0%B4%D0%BE%D0%BA%D0%B8%D1%8F'],
#  ['Евпраксия',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D0%BF%D1%80%D0%B0%D0%BA%D1%81%D0%B8%D1%8F'],
#  ['Евфимия',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%B2%D1%84%D0%B8%D0%BC%D0%B8%D1%8F'],
#  ['Екатерина',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%BA%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%BD%D0%B0'],
#  ['Елена', 'https://ru.wikipedia.org/wiki/%D0%95%D0%BB%D0%B5%D0%BD%D0%B0'],
#  ['Елизавета',
#   'https://ru.wikipedia.org/wiki/%D0%95%D0%BB%D0%B8%D0%B7%D0%B0%D0%B2%D0%B5%D1%82%D0%B0'],
#  ['Ермиония',
#   'https://ru.wikipedia.org/wiki/%D0%95%D1%80%D0%BC%D0%B8%D0%BE%D0%BD%D0%B8%D1%8F'],
#  ['Жаклин',
#   'https://ru.wikipedia.org/wiki/%D0%96%D0%B0%D0%BA%D0%BB%D0%B8%D0%BD_(%D0%B8%D0%BC%D1%8F)'],
#  ['Жанетт',
#   'https://ru.wikipedia.org/wiki/%D0%96%D0%B0%D0%BD%D0%B5%D1%82%D1%82'],
#  ['Женевьева',
#   'https://ru.wikipedia.org/wiki/%D0%96%D0%B5%D0%BD%D0%B5%D0%B2%D1%8C%D0%B5%D0%B2%D0%B0'],
#  ['Забава',
#   'https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%B1%D0%B0%D0%B2%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Зинаида',
#   'https://ru.wikipedia.org/wiki/%D0%97%D0%B8%D0%BD%D0%B0%D0%B8%D0%B4%D0%B0'],
#  ['Зоя', 'https://ru.wikipedia.org/wiki/%D0%97%D0%BE%D1%8F'],
#  ['Зульфия',
#   'https://ru.wikipedia.org/wiki/%D0%97%D1%83%D0%BB%D1%8C%D1%84%D0%B8%D1%8F'],
#  ['Ивета', 'https://ru.wikipedia.org/wiki/%D0%98%D0%B2%D0%B5%D1%82%D0%B0'],
#  ['Изабелла',
#   'https://ru.wikipedia.org/wiki/%D0%98%D0%B7%D0%B0%D0%B1%D0%B5%D0%BB%D0%BB%D0%B0'],
#  ['Илона', 'https://ru.wikipedia.org/wiki/%D0%98%D0%BB%D0%BE%D0%BD%D0%B0'],
#  ['Ильзе',
#   'https://ru.wikipedia.org/wiki/%D0%98%D0%BB%D1%8C%D0%B7%D0%B5_(%D0%B8%D0%BC%D1%8F)'],
#  ['Инга',
#   'https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B3%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Инге', 'https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B3%D0%B5'],
#  ['Иоанна',
#   'https://ru.wikipedia.org/wiki/%D0%98%D0%BE%D0%B0%D0%BD%D0%BD%D0%B0'],
#  ['Иоланта',
#   'https://ru.wikipedia.org/wiki/%D0%98%D0%BE%D0%BB%D0%B0%D0%BD%D1%82%D0%B0'],
#  ['Ираида',
#   'https://ru.wikipedia.org/wiki/%D0%98%D1%80%D0%B0%D0%B8%D0%B4%D0%B0'],
#  ['Ирина', 'https://ru.wikipedia.org/wiki/%D0%98%D1%80%D0%B8%D0%BD%D0%B0'],
#  ['Ирма', 'https://ru.wikipedia.org/wiki/%D0%98%D1%80%D0%BC%D0%B0'],
#  ['Иулия', 'https://ru.wikipedia.org/wiki/%D0%98%D1%83%D0%BB%D0%B8%D1%8F'],
#  ['Ия', 'https://ru.wikipedia.org/wiki/%D0%98%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Йенни', 'https://ru.wikipedia.org/wiki/%D0%99%D0%B5%D0%BD%D0%BD%D0%B8'],
#  ['Кайли',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%B9%D0%BB%D0%B8_(%D0%B8%D0%BC%D1%8F)'],
#  ['Камилла',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BC%D0%B8%D0%BB%D0%BB%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Камиля',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BC%D0%B8%D0%BB%D1%8F'],
#  ['Кара',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Карен',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%80%D0%B5%D0%BD_(%D0%B8%D0%BC%D1%8F)'],
#  ['Карина',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%80%D0%B8%D0%BD%D0%B0'],
#  ['Карла', 'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%80%D0%BB%D0%B0'],
#  ['Каролина',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%80%D0%BE%D0%BB%D0%B8%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Кира', 'https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%80%D0%B0'],
#  ['Клавдия',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%BB%D0%B0%D0%B2%D0%B4%D0%B8%D1%8F'],
#  ['Клара', 'https://ru.wikipedia.org/wiki/%D0%9A%D0%BB%D0%B0%D1%80%D0%B0'],
#  ['Клементина',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%BB%D0%B5%D0%BC%D0%B5%D0%BD%D1%82%D0%B8%D0%BD%D0%B0'],
#  ['Констанция',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BD%D1%81%D1%82%D0%B0%D0%BD%D1%86%D0%B8%D1%8F'],
#  ['Консуэло',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BD%D1%81%D1%83%D1%8D%D0%BB%D0%BE'],
#  ['Корнелия',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D0%BD%D0%B5%D0%BB%D0%B8%D1%8F'],
#  ['Кристина',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D1%80%D0%B8%D1%81%D1%82%D0%B8%D0%BD%D0%B0'],
#  ['Ксения',
#   'https://ru.wikipedia.org/wiki/%D0%9A%D1%81%D0%B5%D0%BD%D0%B8%D1%8F'],
#  ['Лада',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Ламия',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D0%BC%D0%B8%D1%8F_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)'],
#  ['Лана',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Лаодика',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D0%BE%D0%B4%D0%B8%D0%BA%D0%B0'],
#  ['Лариса',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D1%80%D0%B8%D1%81%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Лаура',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B0%D1%83%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Лейла', 'https://ru.wikipedia.org/wiki/%D0%9B%D0%B5%D0%B9%D0%BB%D0%B0'],
#  ['Лейсан',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B5%D0%B9%D1%81%D0%B0%D0%BD'],
#  ['Леля', 'https://ru.wikipedia.org/wiki/%D0%9B%D0%B5%D0%BB%D1%8F'],
#  ['Лина', 'https://ru.wikipedia.org/wiki/%D0%9B%D0%B8%D0%BD%D0%B0'],
#  ['Линнея',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B8%D0%BD%D0%BD%D0%B5%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Лия', 'https://ru.wikipedia.org/wiki/%D0%9B%D0%B8%D1%8F'],
#  ['Лия',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%B8%D1%8F_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)'],
#  ['Лора',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D0%BE%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Лукия', 'https://ru.wikipedia.org/wiki/%D0%9B%D1%83%D0%BA%D0%B8%D1%8F'],
#  ['Любовь',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D1%8E%D0%B1%D0%BE%D0%B2%D1%8C_(%D0%B8%D0%BC%D1%8F)'],
#  ['Людмила',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D1%8E%D0%B4%D0%BC%D0%B8%D0%BB%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Людовика',
#   'https://ru.wikipedia.org/wiki/%D0%9B%D1%8E%D0%B4%D0%BE%D0%B2%D0%B8%D0%BA%D0%B0'],
#  ['Магали',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%B3%D0%B0%D0%BB%D0%B8'],
#  ['Магдалина',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%B3%D0%B4%D0%B0%D0%BB%D0%B8%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Мадина',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%B4%D0%B8%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Майя',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%B9%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Мальвина',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%BB%D1%8C%D0%B2%D0%B8%D0%BD%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Маргарет',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B3%D0%B0%D1%80%D0%B5%D1%82'],
#  ['Маргарита',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B3%D0%B0%D1%80%D0%B8%D1%82%D0%B0'],
#  ['Марианна',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B8%D0%B0%D0%BD%D0%BD%D0%B0'],
#  ['Марина',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B8%D0%BD%D0%B0'],
#  ['Мариса',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B8%D1%81%D0%B0'],
#  ['Марисоль',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B8%D1%81%D0%BE%D0%BB%D1%8C'],
#  ['Мария',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Марлен',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D0%BB%D0%B5%D0%BD'],
#  ['Марфа', 'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%80%D1%84%D0%B0'],
#  ['Мастридия',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%81%D1%82%D1%80%D0%B8%D0%B4%D0%B8%D1%8F'],
#  ['Матрёна',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%82%D1%80%D1%91%D0%BD%D0%B0'],
#  ['Мафтуха',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%84%D1%82%D1%83%D1%85%D0%B0'],
#  ['Мелания',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%BB%D0%B0%D0%BD%D0%B8%D1%8F'],
#  ['Мелисса',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%BB%D0%B8%D1%81%D1%81%D0%B0'],
#  ['Милица',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D0%BB%D0%B8%D1%86%D0%B0'],
#  ['Мирей', 'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%80%D0%B5%D0%B9'],
#  ['Миропия',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%80%D0%BE%D0%BF%D0%B8%D1%8F'],
#  ['Мирослава',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%80%D0%BE%D1%81%D0%BB%D0%B0%D0%B2%D0%B0'],
#  ['Мирра',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%80%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Михримах',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%85%D1%80%D0%B8%D0%BC%D0%B0%D1%85'],
#  ['Мод',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B4_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)'],
#  ['Мэдисон',
#   'https://ru.wikipedia.org/wiki/%D0%9C%D1%8D%D0%B4%D0%B8%D1%81%D0%BE%D0%BD_(%D0%B8%D0%BC%D1%8F)'],
#  ['Мэри', 'https://ru.wikipedia.org/wiki/%D0%9C%D1%8D%D1%80%D0%B8'],
#  ['Мю', 'https://ru.wikipedia.org/wiki/%D0%9C%D1%8E_(%D0%B8%D0%BC%D1%8F)'],
#  ['Надежда',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%B4%D0%B5%D0%B6%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Наджия',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%B4%D0%B6%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Надия',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%B4%D0%B8%D1%8F_(%D0%B8%D0%BC%D1%8F)'],
#  ['Назгуль',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%B7%D0%B3%D1%83%D0%BB%D1%8C'],
#  ['Наоми',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BE%D0%BC%D0%B8_(%D0%B8%D0%BC%D1%8F)'],
#  ['Наталья',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%82%D0%B0%D0%BB%D1%8C%D1%8F'],
#  ['Нелли', 'https://ru.wikipedia.org/wiki/%D0%9D%D0%B5%D0%BB%D0%BB%D0%B8'],
#  ['Неонилла',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B5%D0%BE%D0%BD%D0%B8%D0%BB%D0%BB%D0%B0'],
#  ['Ника',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%BA%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Николетта',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%BA%D0%BE%D0%BB%D0%B5%D1%82%D1%82%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Нилуфар',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%BB%D1%83%D1%84%D0%B0%D1%80_(%D0%B8%D0%BC%D1%8F)'],
#  ['Нинель',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%BD%D0%B5%D0%BB%D1%8C'],
#  ['Ноа', 'https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%B0'],
#  ['Нонна', 'https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D0%BD%D0%BD%D0%B0'],
#  ['Нора',
#   'https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Нэнси', 'https://ru.wikipedia.org/wiki/%D0%9D%D1%8D%D0%BD%D1%81%D0%B8'],
#  ['Одетта',
#   'https://ru.wikipedia.org/wiki/%D0%9E%D0%B4%D0%B5%D1%82%D1%82%D0%B0'],
#  ['Октавия',
#   'https://ru.wikipedia.org/wiki/%D0%9E%D0%BA%D1%82%D0%B0%D0%B2%D0%B8%D1%8F'],
#  ['Октябрина',
#   'https://ru.wikipedia.org/wiki/%D0%9E%D0%BA%D1%82%D1%8F%D0%B1%D1%80%D0%B8%D0%BD%D0%B0'],
#  ['Олимпиада',
#   'https://ru.wikipedia.org/wiki/%D0%9E%D0%BB%D0%B8%D0%BC%D0%BF%D0%B8%D0%B0%D0%B4%D0%B0_(%D0%B8%D0%BC%D1%8F)'],
#  ['Ольга', 'https://ru.wikipedia.org/wiki/%D0%9E%D0%BB%D1%8C%D0%B3%D0%B0'],
#  ['Павла', 'https://ru.wikipedia.org/wiki/%D0%9F%D0%B0%D0%B2%D0%BB%D0%B0']]

# %%
tmp="Аарон (имя)"

# %%
tmp
# Out:
# 'Аарон (имя)'
